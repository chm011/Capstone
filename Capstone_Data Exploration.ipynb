# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import data
#df = pd.read_csv("Combined_LCA_Disclosure_Data_FY2022.csv", low_memory=False)
df = pd.read_csv('Combined_LCA_Disclosure_Data_FY2020_to_FY2024.csv', low_memory=False)
#df = pd.read_csv("/Users/seonminhwang/Downloads/archive (1)/Combined_LCA_Disclosure_Data_FY2022.csv", low_memory=False)

# %%
df.head(5)
# Out:
#           CASE_NUMBER CASE_STATUS RECEIVED_DATE DECISION_DATE  \
# 0  I-200-19268-393467   Certified    2019-09-25    2019-10-01
# 1  I-200-19268-638983   Certified    2019-09-25    2019-10-01
# 2  I-200-19268-177184   Certified    2019-09-25    2019-10-01
# 3  I-200-19268-936403   Certified    2019-09-25    2019-10-01
# 4  I-200-19268-394079   Certified    2019-09-25    2019-10-01
#
#   ORIGINAL_CERT_DATE VISA_CLASS                               JOB_TITLE  \
# 0                NaN       H-1B  APPLICATION ENGINEER, OMS [15-1199.02]
# 1                NaN       H-1B                         BI DEVELOPER II
# 2                NaN       H-1B                        QUALITY ENGINEER
# 3                NaN       H-1B        SOFTWARE DEVELOPER, APPLICATIONS
# 4                NaN       H-1B               QUALITY ENGINEER LEVEL II
#
#   SOC_CODE                          SOC_TITLE FULL_TIME_POSITION  ...  \
# 0  15-1199    COMPUTER OCCUPATIONS, ALL OTHER                  Y  ...
# 1  15-1132  SOFTWARE DEVELOPERS, APPLICATIONS                  Y  ...
# 2  17-2141               MECHANICAL ENGINEERS                  Y  ...
# 3  15-1132  SOFTWARE DEVELOPERS, APPLICATIONS                  Y  ...
# 4  15-1199    COMPUTER OCCUPATIONS, ALL OTHER                  Y  ...
#
#   WILLFUL_VIOLATOR SUPPORT_H1B  STATUTORY_BASIS  APPENDIX_A_ATTACHED  \
# 0                N         NaN              NaN                  NaN
# 1                N           Y             BOTH                  NaN
# 2                N           Y             BOTH                  NaN
# 3                N           Y             BOTH                  NaN
# 4                N           Y             BOTH                  NaN
#
#    PUBLIC_DISCLOSURE  PREPARER_LAST_NAME  PREPARER_FIRST_NAME  \
# 0  Disclose Business                 NaN                  NaN
# 1  Disclose Business                 NaN                  NaN
# 2  Disclose Business                 NaN                  NaN
# 3  Disclose Business                 NaN                  NaN
# 4  Disclose Business                 NaN                  NaN
#
#    PREPARER_MIDDLE_INITIAL  PREPARER_BUSINESS_NAME        PREPARER_EMAIL
# 0                      NaN                     NaN                   NaN
# 1                      NaN                     NaN                   NaN
# 2                      NaN                     NaN                   NaN
# 3                      NaN                     NaN                   NaN
# 4                      NaN                     NaN  LEGAL@THEEGIANTS.COM
#
# [5 rows x 96 columns]

# %%
#checking for missing value
df.isnull()
# Out:
#        CASE_NUMBER  CASE_STATUS  RECEIVED_DATE  DECISION_DATE  \
# 0            False        False          False          False
# 1            False        False          False          False
# 2            False        False          False          False
# 3            False        False          False          False
# 4            False        False          False          False
# ...            ...          ...            ...            ...
# 18297        False        False          False          False
# 18298        False        False          False          False
# 18299        False        False          False          False
# 18300        False        False          False          False
# 18301        False         True           True           True
#
#        ORIGINAL_CERT_DATE  VISA_CLASS  JOB_TITLE  SOC_CODE  SOC_TITLE  \
# 0                    True       False      False     False      False
# 1                    True       False      False     False      False
# 2                    True       False      False     False      False
# 3                    True       False      False     False      False
# 4                    True       False      False     False      False
# ...                   ...         ...        ...       ...        ...
# 18297                True       False      False     False      False
# 18298                True       False      False     False      False
# 18299                True       False      False     False      False
# 18300                True       False      False     False      False
# 18301                True        True       True      True       True
#
#        FULL_TIME_POSITION  ...  WILLFUL_VIOLATOR  SUPPORT_H1B  \
# 0                   False  ...             False         True
# 1                   False  ...             False        False
# 2                   False  ...             False        False
# 3                   False  ...             False        False
# 4                   False  ...             False        False
# ...                   ...  ...               ...          ...
# 18297               False  ...             False         True
# 18298               False  ...             False         True
# 18299               False  ...             False         True
# 18300               False  ...             False        False
# 18301                True  ...              True         True
#
#        STATUTORY_BASIS  APPENDIX_A_ATTACHED  PUBLIC_DISCLOSURE  \
# 0                 True                 True              False
# 1                False                 True              False
# 2                False                 True              False
# 3                False                 True              False
# 4                False                 True              False
# ...                ...                  ...                ...
# 18297             True                 True              False
# 18298             True                 True              False
# 18299             True                 True              False
# 18300            False                 True              False
# 18301             True                 True               True
#
#        PREPARER_LAST_NAME  PREPARER_FIRST_NAME  PREPARER_MIDDLE_INITIAL  \
# 0                    True                 True                     True
# 1                    True                 True                     True
# 2                    True                 True                     True
# 3                    True                 True                     True
# 4                    True                 True                     True
# ...                   ...                  ...                      ...
# 18297                True                 True                     True
# 18298                True                 True                     True
# 18299               False                False                    False
# 18300               False                False                    False
# 18301                True                 True                     True
#
#        PREPARER_BUSINESS_NAME  PREPARER_EMAIL
# 0                        True            True
# 1                        True            True
# 2                        True            True
# 3                        True            True
# 4                        True           False
# ...                       ...             ...
# 18297                    True            True
# 18298                    True            True
# 18299                   False           False
# 18300                   False           False
# 18301                    True            True
#
# [18302 rows x 96 columns]

# %%
# Display basic information about the dataset
print("Dataset Info:")
df.info()
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18302 entries, 0 to 18301
# Data columns (total 96 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   CASE_NUMBER                     18302 non-null  object
#  1   CASE_STATUS                     18301 non-null  object
#  2   RECEIVED_DATE                   18301 non-null  object
#  3   DECISION_DATE                   18301 non-null  object
#  4   ORIGINAL_CERT_DATE              2051 non-null   object
#  5   VISA_CLASS                      18301 non-null  object
#  6   JOB_TITLE                       18300 non-null  object
#  7   SOC_CODE                        18301 non-null  object
#  8   SOC_TITLE                       18301 non-null  object
#  9   FULL_TIME_POSITION              18301 non-null  object
#  10  BEGIN_DATE                      18301 non-null  object
#  11  END_DATE                        18301 non-null  object
#  12  TOTAL_WORKER_POSITIONS          18301 non-null  float64
#  13  NEW_EMPLOYMENT                  18301 non-null  float64
#  14  CONTINUED_EMPLOYMENT            18301 non-null  float64
#  15  CHANGE_PREVIOUS_EMPLOYMENT      18301 non-null  float64
#  16  NEW_CONCURRENT_EMPLOYMENT       18301 non-null  float64
#  17  CHANGE_EMPLOYER                 18301 non-null  float64
#  18  AMENDED_PETITION                18301 non-null  float64
#  19  EMPLOYER_NAME                   18300 non-null  object
#  20  TRADE_NAME_DBA                  1649 non-null   object
#  21  EMPLOYER_ADDRESS1               18301 non-null  object
#  22  EMPLOYER_ADDRESS2               8563 non-null   object
#  23  EMPLOYER_CITY                   18301 non-null  object
#  24  EMPLOYER_STATE                  18301 non-null  object
#  25  EMPLOYER_POSTAL_CODE            18301 non-null  object
#  26  EMPLOYER_COUNTRY                18301 non-null  object
#  27  EMPLOYER_PROVINCE               472 non-null    object
#  28  EMPLOYER_PHONE                  18301 non-null  object
#  29  EMPLOYER_PHONE_EXT              1069 non-null   float64
#  30  NAICS_CODE                      18301 non-null  float64
#  31  EMPLOYER_POC_LAST_NAME          18300 non-null  object
#  32  EMPLOYER_POC_FIRST_NAME         18301 non-null  object
#  33  EMPLOYER_POC_MIDDLE_NAME        3763 non-null   object
#  34  EMPLOYER_POC_JOB_TITLE          18300 non-null  object
#  35  EMPLOYER_POC_ADDRESS1           18301 non-null  object
#  36  EMPLOYER_POC_ADDRESS2           8789 non-null   object
#  37  EMPLOYER_POC_CITY               18301 non-null  object
#  38  EMPLOYER_POC_STATE              18295 non-null  object
#  39  EMPLOYER_POC_POSTAL_CODE        18301 non-null  object
#  40  EMPLOYER_POC_COUNTRY            18301 non-null  object
#  41  EMPLOYER_POC_PROVINCE           104 non-null    object
#  42  EMPLOYER_POC_PHONE              18301 non-null  object
#  43  EMPLOYER_POC_PHONE_EXT          1302 non-null   float64
#  44  EMPLOYER_POC_EMAIL              18147 non-null  object
#  45  AGENT_REPRESENTING_EMPLOYER     18301 non-null  object
#  46  AGENT_ATTORNEY_LAST_NAME        11711 non-null  object
#  47  AGENT_ATTORNEY_FIRST_NAME       11711 non-null  object
#  48  AGENT_ATTORNEY_MIDDLE_NAME      7317 non-null   object
#  49  AGENT_ATTORNEY_ADDRESS1         11711 non-null  object
#  50  AGENT_ATTORNEY_ADDRESS2         8813 non-null   object
#  51  AGENT_ATTORNEY_CITY             11711 non-null  object
#  52  AGENT_ATTORNEY_STATE            11376 non-null  object
#  53  AGENT_ATTORNEY_POSTAL_CODE      11711 non-null  object
#  54  AGENT_ATTORNEY_COUNTRY          11711 non-null  object
#  55  AGENT_ATTORNEY_PROVINCE         582 non-null    object
#  56  AGENT_ATTORNEY_PHONE            11711 non-null  float64
#  57  AGENT_ATTORNEY_PHONE_EXT        1100 non-null   float64
#  58  AGENT_ATTORNEY_EMAIL_ADDRESS    11709 non-null  object
#  59  LAWFIRM_NAME_BUSINESS_NAME      11706 non-null  object
#  60  STATE_OF_HIGHEST_COURT          11687 non-null  object
#  61  NAME_OF_HIGHEST_STATE_COURT     11688 non-null  object
#  62  WORKSITE_WORKERS                6967 non-null   float64
#  63  SECONDARY_ENTITY                17341 non-null  object
#  64  SECONDARY_ENTITY_BUSINESS_NAME  7799 non-null   object
#  65  WORKSITE_ADDRESS1               18301 non-null  object
#  66  WORKSITE_ADDRESS2               4146 non-null   object
#  67  WORKSITE_CITY                   18301 non-null  object
#  68  WORKSITE_COUNTY                 18291 non-null  object
#  69  WORKSITE_STATE                  18301 non-null  object
#  70  WORKSITE_POSTAL_CODE            18301 non-null  object
#  71  WAGE_RATE_OF_PAY_FROM           18301 non-null  float64
#  72  WAGE_RATE_OF_PAY_TO             7292 non-null   float64
#  73  WAGE_UNIT_OF_PAY                18301 non-null  object
#  74  PREVAILING_WAGE                 17342 non-null  float64
#  75  PW_UNIT_OF_PAY                  17342 non-null  object
#  76  PW_TRACKING_NUMBER              64 non-null     object
#  77  PW_WAGE_LEVEL                   16561 non-null  object
#  78  PW_OES_YEAR                     16576 non-null  object
#  79  PW_OTHER_SOURCE                 10702 non-null  object
#  80  PW_OTHER_YEAR                   327 non-null    float64
#  81  PW_SURVEY_PUBLISHER             587 non-null    object
#  82  PW_SURVEY_NAME                  258 non-null    object
#  83  TOTAL_WORKSITE_LOCATIONS        6967 non-null   float64
#  84  AGREE_TO_LC_STATEMENT           18301 non-null  object
#  85  H_1B_DEPENDENT                  17757 non-null  object
#  86  WILLFUL_VIOLATOR                17756 non-null  object
#  87  SUPPORT_H1B                     7449 non-null   object
#  88  STATUTORY_BASIS                 7149 non-null   object
#  89  APPENDIX_A_ATTACHED             12 non-null     object
#  90  PUBLIC_DISCLOSURE               18296 non-null  object
#  91  PREPARER_LAST_NAME              7519 non-null   object
#  92  PREPARER_FIRST_NAME             7519 non-null   object
#  93  PREPARER_MIDDLE_INITIAL         3686 non-null   object
#  94  PREPARER_BUSINESS_NAME          7790 non-null   object
#  95  PREPARER_EMAIL                  8077 non-null   object
# dtypes: float64(18), object(78)
# memory usage: 13.4+ MB

# %%
# Total number of applications over the years (2020-2024)
df['YEAR'] = pd.to_datetime(df['DECISION_DATE']).dt.year  # Extract year from decision date
yearly_applications = df['YEAR'].value_counts().sort_index()

plt.figure(figsize=(10, 6))
plt.bar(yearly_applications.index, yearly_applications.values, color='skyblue')
plt.title('Total H1B Applications by Year', fontsize=16)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Number of Applications', fontsize=12)
plt.xticks(yearly_applications.index)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Distribution of case statuses
case_status_counts = df['CASE_STATUS'].value_counts()

# Case status distribution using pie chart
plt.figure(figsize=(8, 8))
case_status_counts.plot(kind='pie', startangle=90, cmap='Set3', legend=True)
plt.title('Case Status Distribution', fontsize=16)
plt.ylabel('')  # Remove y-label for better appearance
plt.show()

# %%
# Top occupations in the dataset
top_occupations = df['JOB_TITLE'].value_counts().head(10)

plt.figure(figsize=(10, 6))
top_occupations.plot(kind='barh', color='lightgreen', edgecolor='black')
plt.title('Top 10 Occupations in H1B Applications', fontsize=16)
plt.xlabel('Number of Applications', fontsize=12)
plt.ylabel('Occupation', fontsize=12)
plt.gca().invert_yaxis()
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()

# %%
# Salary Analysis
# Clean and convert salaries to numeric, handling outliers
df['PREVAILING_WAGE'] = pd.to_numeric(df['PREVAILING_WAGE'], errors='coerce')
df = df[df['PREVAILING_WAGE'] > 0]  # Filter out non-positive values

# %%
 # Plot salary distribution
plt.figure(figsize=(12, 6))
sns.histplot(df['PREVAILING_WAGE'], bins=100, kde=True, color='blue')
plt.title('Distribution of Prevailing Wages', fontsize=16)
plt.xlabel('Prevailing Wage', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.xlim(0, df['PREVAILING_WAGE'].quantile(0.99))  # Limit to 99th percentile to remove outliers
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %%
# Analyze average salaries by occupation
avg_salaries = df.groupby('SOC_TITLE')['PREVAILING_WAGE'].mean().sort_values(ascending=False).head(10)

plt.figure(figsize=(10, 6))
avg_salaries.plot(kind='barh', color='purple', edgecolor='black')
plt.title('Top 10 Occupations by Average Prevailing Wage', fontsize=16)
plt.xlabel('Average Prevailing Wage', fontsize=12)
plt.ylabel('Occupation', fontsize=12)
plt.gca().invert_yaxis()
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()

# %%
# Analyze average salaries by occupation
avg_salaries_rev = df.groupby('SOC_TITLE')['PREVAILING_WAGE'].mean().sort_values(ascending=True).head(10)

plt.figure(figsize=(10, 6))
avg_salaries_rev.plot(kind='barh', color='purple', edgecolor='black')
plt.title('Lowest 10 Occupations by Average Prevailing Wage', fontsize=16)
plt.xlabel('Average Prevailing Wage', fontsize=12)
plt.ylabel('Occupation', fontsize=12)
plt.gca().invert_yaxis()
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()

# %%
# Case Status Insights
# Calculate approval rates by year
yearly_status = df.groupby('YEAR')['CASE_STATUS'].value_counts(normalize=True).unstack().fillna(0)

plt.figure(figsize=(12, 6))
for status in yearly_status.columns:
    plt.plot(yearly_status.index, yearly_status[status], marker='o', label=status)

plt.title('H1B Case Status Trends by Year', fontsize=16)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Proportion of Cases', fontsize=12)
plt.legend(title='Case Status')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()
